# %%
# Data science
# lab session 2 - probability and linear algebra for data science

# %%
import numpy as np
from scipy import stats
import math as mt
import random as rnd

# %%
# matrix operations

# np.array() converts Python data (lists or tuples) into a NumPy array object.
# NumPy performs element-wise addition.
# It adds each element in the same position.

# `np.array()` → creates a mathematical matrix  
# `+` and `-` → element-wise operations  
# `np.dot()` → true matrix multiplication 

x = np.array( ((2, 3), (3, 5) ))
# [ 2   3 ]
# [ 3   5 ]
y = np.array( ((1, 2), (5, -1)))
# [ 1   2 ]
# [ 5  -1 ]

# Each one is a 2×2 matrix.
# What is a MATRIX MULTIPLICATION
# You multiply a row from the first matrix
# with a column from the second matrix
# and add the results.


addition = x + y
print("x:", x)
print("y:", y)
print("addition of x and y is", addition)

subtraction = x - y
print("difference between x and y", subtraction)

# [ 2   3 ]
# [ 3   5 ]

# [ 1   2 ]
# [ 5  -1 ]

# Row 1 of x → [2, 3]
# Column 1 of y → [1, 5]

# Now multiply matching positions:

# (2 × 1) + (3 × 5) = 17 - the first value in the result matrix [17  ?] [?   ?]
# (2 * 2) + (3 * -1) = 1 - the next value [17   1] [?  ?]

# Row 2 of x → [3, 5]
# Column 1 of y → [1, 5]
# (3 * 1) + (5 * 5) = 28 - [17  1] [28  ?]
# (3 * 2) + (5 * -1) = 1 => [17 1] [28 1]

# Matrix multiplication means:
# Take a row from X
# Take a column from Y
# Multiply matching elements
# Add them
# That gives one output value
# Repeat for all columns of Y
# Then move to next row of X
dot_product = np.dot(x, y)
print("dot product of x and y", dot_product)
# Out:
# x: [[2 3]
#  [3 5]]
# y: [[ 1  2]
#  [ 5 -1]]
# addition of x and y is [[3 5]
#  [8 4]]
# difference between x and y [[ 1  1]
#  [-2  6]]
# dot product of x and y [[17  1]
#  [28  1]]

# %%
# matrix() function of numpy
# for np.matrix objects
# '*' means matrix multiplication, in here: x * y is equivalent to np.dot(x, y)
# BUT for np.array, x * y is element wise multiplication
x = np.matrix( ((2, 3), (3, 5)))
y = np.matrix( ((1, 2), (5, -1)))
print(x)
print(y)

multiplication = x*y
print("multiplicaiton of x and y:\n", multiplication)

# best practice do not use np.matrix(), use array and x @ y; @ is clean matrix multiplication operator

x = np.array(((2, 3), (3, 5)))
y = np.array(((1, 2), (5, -1)))
print("the modern way using @ operator for matrix multiplication:\n", x @ y)
# Out:
# [[2 3]
#  [3 5]]
# [[ 1  2]
#  [ 5 -1]]
# multiplicaiton of x and y:
#  [[17  1]
#  [28  1]]
# the modern way using @ operator for matrix multiplication:
#  [[17  1]
#  [28  1]]

# %%
# Question 1
# You are given with metrices "a" contains ((45,35), (21,51)) , "b" contains ((1,2), (3,4)) and, 
# "c" contains ((100,101), (200,201)). Now perform the following operations given:

# ***Hint:*** You can either use "array" or "matrix" function.

# 1. a+b
# 2. b-c
# 3. a*c
# 4. b.c

a = np.array(((45,35), (21,51)))
b = np.array(((1,2), (3,4)))
c = np.array(((100,101), (200,201)))

print("a\n", a)
print("b\n", b)
print("c\n", c)

# 1. addition
print("addition of a b\n", a + b)

# 2. subtraction
print("subtraction of b c\n", b - c)

# 3. element wise multiplication
print("element wise multiplication of a and c\n", a * c)

# 4. b.c or b @ c
print("matrix multiplication using dot of b and c\n", np.dot(b, c))
print("matrix multiplication using @ operator between b and c\n", b @ c)
# Out:
# a
#  [[45 35]
#  [21 51]]
# b
#  [[1 2]
#  [3 4]]
# c
#  [[100 101]
#  [200 201]]
# addition of a b
#  [[46 37]
#  [24 55]]
# subtraction of b c
#  [[ -99  -99]
#  [-197 -197]]
# element wise multiplication of a and c
#  [[ 4500  3535]
#  [ 4200 10251]]
# matrix multiplication using dot of b and c
#  [[ 500  503]
#  [1100 1107]]
# matrix multiplication using @ operator between b and c
#  [[ 500  503]
#  [1100 1107]]

# %%
# Vector operations

x = np.array([1, 2, 5])
y = np.array([5, -1, 6])
print(x)
print(y)
addition = x + y
print("addition of x anpd y", addition)

print("differnece between x and y\n", x - y)
# dot product in vectors:
# multiply matching position and add the results

# x = [a, b, c]
# y = [d, e, f]
# dot = (a×d) + (b×e) + (c×f)

# x * y in arrays = element-wise multiplication, the result will still be a vector
print("dot product of x and y\n", np.dot(x, y))
# Out:
# [1 2 5]
# [ 5 -1  6]
# addition of x anpd y [ 6  1 11]
# differnece between x and y
#  [-4  3 -1]
# dot product of x and y
#  33

# %%
# Vector modulus
x = np.array([1, 2, 3, 4, 5])

modulus = np.sqrt(np.dot(x, x)) # dot(v, v), dot product of the x with itself; and returns square root of the product
print(np.sqrt(55))
print(modulus)
# Out:
# 7.416198487095663
# 7.416198487095663

# %%
# multiplication of vector with a scalar value; multiply() function
# scalar means multiply every element in the vector by that number
vector = np.array([1, 2, 3])
n = 100
print(np.multiply(vector, n))
print(vector * n)
# Out:
# [100 200 300]
# [100 200 300]

# %%
# Question 2
# You are given with a vector/1D matrix, ([90,200,20,1,54,200]) contains the club card points 
# he earned on different occassions. You are giving him 2 times more points and 
# you want to store that 2 times rewarded points in a new vector/1D array. 
# Write a code to store this infomation. 

my_vector = np.array([90,200,20,1,54,200])
print(my_vector)
new_vector = my_vector * 2
print("doubled points in the card:", new_vector)
# Out:
# [ 90 200  20   1  54 200]
# doubled points in the card: [180 400  40   2 108 400]

# %%
# Generating Binominal Distribution
"""
binominal distribution
it models the number of successes in a fixed number of independent trials.
it is used when: 
- you repeat an experiment n times; 
- each trial has only two outcomes (success or failure)
- the probability success p stays the same
ex: tossing a coin 10 times and counting how many heads apper
"""
# n - number of trials
# p - probability of success in each trial
X = stats.binom(10, 0.2) # n = 10; p = 0.2 - 20% chance of success each time
# X - REPRESENTS THE NUMBER OF SUCCESSES IN n TRIALS, WHERE EACH TRIAL HAS PROBABILITY p OF SUCCESS.
"""
PMF (probability mass function) - the probability of getting exactly k successes
CDF (cumulative distribution function) - the probability of getting k or fewer successes
Mean = n * p; the mean is the average value you expect if you repeat the experiment many times
Variance = n*p*(1-p) - it tells how spread out the results are from the mean,
    it measures how much the outcomes fluctute;
    if variance is small - results stay close to the mean
    if variance is large - results are more spread out
Standard deviation (std) - std = sqrt(variance)
    it measures spread like variance, but it is in the same units as the data and it is easier to understand

mean = 2 -> average number of successes is 2
std = 1.26 -> most results are roughly withing 1.26 of 2; so most outcomes will be 2 +- 1.26
"""
print(X.rvs()) # number of successes in n time trial where success chance is 20%
print(X.pmf(3)) # P(X=3)probability of getting exactly 3 successes out of 10
print(X.cdf(4)) # P(X <= 4) probability of getting at most 4 successes
print(X.mean())
print(X.var())
print(X.std())
# Out:
# 3
# 0.20132659199999992
# 0.9672065024
# 2.0
# 1.5999999999999999
# 1.2649110640673518

# %%
# Question 3
# You are given a dice which you can roll five times to check how many times you find "6" 
# and probability of the roll being a success is 80%.  
# Write a code to find the probability mass function (pmf) 
# and cumulative distribution function (cdf) for the final trial.

X = stats.binom(5, 0.8) # = totoal number of successes in 5 rolls
pmf = X.pmf(5) # what is the probability that all 5 rolls are success;/ probability of 5 successes 
print(pmf)

print(X.cdf(5))
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
# 0.3276800000000002
# 1.0

# %%
# Generating normal distribution
# Mean → center of curve
# Variance → spread
# Standard deviation → square root of variance
# PDF → height of curve
# CDF → actual probability up to a point
A = stats.norm(3, mt.sqrt(16)) # mean = 3, standard deviation = 4, where variance is 16
print(A.pdf(4))
print(A.cdf(2))
# Out:
# 0.09666702920071232
# 0.4012936743170763

# %%
# Question 4
# Write a code to calculate the probability density function and 
# cumulative distrbution function for a normal distribution 
# with $μ=9 ,σ^2=64$, for probability density equals 6

A = stats.norm(9, mt.sqrt(64))
print("pdf:", A.pdf(6))
print("cdf:", A.cdf(6))
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
# pdf: 0.04648188673372112
# cdf: 0.3538302333272762

# %%
# Question 5
# Write a code to calculate the normal probability density function for value "11" 
# in the range, given, mean=10 and standard deviation=2.
# **Hint:** remember to use standard deviation instead of variance in the code.
A = stats.norm(10, 2)
print(A.pdf(11))
# Out:
# 0.17603266338214976

# %%
# Calculating Probability and Conditional probability

def toss_coin(n):
    trials = []
    for i in range(n):
        trials.append(rnd.random() <= 0.5) # rnd.random() = random numbeer between 0 and 1, if this number is <= 0.5 then it is true, it is heads
        # if greater it is tails, it is storing true or false values in trials
        # print(trials)
    return sum(trials) # and here we are calculating all the oens or trues, which gives us how many times we got 1s

def probability(n, e): # n - total tosses, e - number of heads
    probability_heads = (e/n)
    return probability_heads

n = 10
probability_heads = probability(n, toss_coin(n))
print("sum: ", toss_coin(n))
print(probability_heads)

n = 100
probability_heads = probability(n, toss_coin(n))
print(probability_heads)

n = 1000
probability_heads = probability(n, toss_coin(n))
print(probability_heads)
# Out:
# sum:  4
# 0.8
# 0.48
# 0.525

# %%
# Question 6
# Now, calculate the probability of finding  "Tails" when you toss a **fair coin** with 50% or 
# more will be the probability of getting tail from random fair flips.

# Write a code to calculate the probability of getting head when we do  **ten, hundred, and thousand** trials of flip

def toss_coin(n):
    trials = []
    for _ in range(n):
        trials.append(rnd.random() >= 0.5) # return true if random number is greater than 0.5, which would mean success/ tail for us
    return sum(trials)

def probability(n, e):
    probability_tails = (e/n)
    return probability_tails

n = 10
probability_tails = probability(n, toss_coin(n))
print(probability_tails)
n = 100
probability_tails = probability(n, toss_coin(n))
print(probability_tails)
n = 10000
probability_tails = probability(n, toss_coin(n))
print(probability_tails)
# Out:
# 0.6
# 0.49
# 0.4979

# %%
# Question 7
# Write a code to find the probability of both Heads and 
# Tails when we do **ten and hundred** trials of flip

def toss_coin(n):
    global trials
    trials = []
    for _ in range(n):
        trials.append(rnd.random() <= 0.5) # return true if less than half, less - heads; more - tails
    return sum(trials)
    
def probability(n, e):
    return e/n

for n in [10, 100, 1000]:
    success = toss_coin(n)  # number of tails (True)
    
    probability_tails = probability(n, success)
    probability_heads = probability(n, n - success)

    print(f"\nn = {n}")
    print("probability of heads:", probability_heads)
    print("probability of tails:", probability_tails)
# Out:
# n = 10
# probability of heads: 0.4
# probability of tails: 0.6
#
# n = 100
# probability of heads: 0.52
# probability of tails: 0.48
#
# n = 1000
# probability of heads: 0.483
# probability of tails: 0.517

# %%
# another example - card game

def event_probability(event_outcomes, sample_space):
    probability = (event_outcomes/sample_space)
    return round(probability, 6)

cards = 52 # sample space
aces = 4 # outcomes
face_cards = 12


# Probability of drawing an ace normally
ace_probability_percent = event_probability(aces, cards) * 100
print(f"probability % of finding ace, rounded to one decimal place: {round(ace_probability_percent, 1)}%")

# -------- Conditional Probability --------
# P(Ace | Face first) => P(A | B) = P(A ∩ B) / P(B)

# Probability of drawing an ace, given you had just drawn a face card 
# if you are the first player (the deck is NOT shuffled after the first draw)

p_face_first = event_probability(face_cards, cards)

# P(Ace second | Face first)
# After removing 1 face card:
# cards left = 51
# aces left = still 4
p_ace_second_given_face = event_probability(aces, cards - 1)

# Joint probability:
p_face_and_ace = p_face_first * p_ace_second_given_face

# Conditional probability:
conditional_probability = p_face_and_ace / p_face_first

print(f"probability % of drawing an ace, given a face card was drawn first: {round(conditional_probability * 100, 3)}%")
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
# probability % of finding ace, rounded to one decimal place: 7.7%
# probability % of drawing an ace, given a face card was drawn first: 7.843%

# %%
# Question 8
# From a given deck of 52 cards you first draw a king. 
# What is the probability of finding another king from the same deck, 
# considering the first card is already outside of the deck now? 
# Write a code to calculate the conditional probability of getting the second card as another king.

def event_probability(poss, outcomes):
    return outcomes/poss

cards = 52
kings = 4

p_of_second_king = event_probability(cards - 1, kings -1)
print("possibility of king consider you already drew king is", round(p_of_second_king*100, 1), "%")
# Out:
# possibility of king consider you already drew king is 5.9 %
