# %% [markdown]
# ## 3. A (nominal, ordinal, binary)
#
# Qualitative: Nominal, Ordinal, (Binary)
#
# Quantitative: Integer/Real-valued, Interval, Ratio
#
# ## 5. B (sample is a selection from entire population)
#
# Population = the full group you care about (everyone/everything in scope).
#
# Sample = a smaller subset chosen from that population to study.
#
# So a sample is literally selected from the population.
#
#
# ## 7. Median (central value, middle value when sorted)
#
# ### Mean (average):
#
# Add everything, divide by how many numbers.
#
# ### Mode
#
# The value that appears most often.
#
# Here, 21 appears twice, others once -> mode is 21.
#
# ### Median
#
# The middle value when sorted.
#
# Less affected by outliers than mean.
#
#
# ## 8. Mode
# The most recurrent value in the array (20, 21, 19, 21, 18, 17, 22, 25) is **21**.
# The most recurrent value is called the **mode**.
#
#
# ## 11. A
# (a) takes height + weight and uses them to classify/predict a new label: T-shirt size (Large/Medium/Small).
#
# Descriptive = describe what you have (mean, median, SD, charts).
#
# Inferential = use data to decide/predict/generalize (estimation, testing, prediction, classification).
#
# ## 12. D
#
# Get data -> choose data -> clean data -> model data (Extract -> Select -> Preprocess -> Mine)
#
#
# # Seminar 2 intro to probability linear algebra for data science
#
# ## 2. C
#
# event A is dependent on event B
