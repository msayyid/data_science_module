# %% [markdown]
# week 4
# introduction ot machine learning approaches for data science
#
# deep learning < machine learning < artificial intelligence
#
# Machine learning is a technique of giving a machine the instruction that enable it to learn form some data the most appropriate process of analyzing that piece fo data and so to find useful patterns and perfom predictions on it withou tbeing explicitly programmed to do so
#
# advantages: easily identifies trends andpatterns, no human intervention needed, continuous improvement, handling multidimensional and multiovariety data web application
#
# disadvantages: data aquisition, time and resources, interpretation of results, high error susceptibility
#
# types of machine learnign
# 1 supervisesd learning - a system is trained with data that has been labelled; the labels categorise each data point into one or more groups, such as 'apples' or 'oranges(simple def needed), 2. unsupervised learning - learning without labels, it aims to detect the characteristics that maek datapoint more or less similar to each other(simple def needed), 3. reinforcement learning(simple def needed)
#
#
# supervised learning : task driven, pre categorized data
#
# unsupervised learnign: data driven, unlabelled data
#
# labeled data - contains meaningul tags and iseused in supervised learning, and unlabled data - no no adidtional information
#
# supervised machine learning: classificaiton (using algorithms to correctly assign thest data to sspecific categories such as seperating jun mail) and regression (using algorithms to undersgtand the relartoihisp between dependetn and independtent variables and forecasting number s basedon different data points such as sales and revenue projections)
#
# unsupervised ml: clustering; association; dimensionality reduction
#
#
# training adn test data/dataset
#
#
# classification is a machine learning approach, that is applied to predict a value (label) assosciated withother features (valeus) in thedata.
# for eample 1. naive bayes (needs simple def)
# 2. k-nn ( nearest neighbor) simple small def: the point value (label) can be approximated by the values closes to it
# the distance of the unseen datapoint is measured with all the existing datapoints and comparing the minimum distances the label for the unseen instance is dtermines
#
#
# linear regression
# continuou s values in andy datesast can be anaylzed and the correlation found from this analysis bcan be used for predicitn theoutput for any unseen datapoints
#
#
# Knn
# naive bayes
# linear regression
#
#
# unsupervised learning - clustering
# algorithm generates labels
#
#
# association rule mining
