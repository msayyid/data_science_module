# %% [markdown]
# 1. Which of the following statement is true about Machine Learning?
# a) ML is a field of Computer Science
# b) ML is an application of AI that is capable to extract patternsfrom data by
# methods/algorithms
# c) ML allows computer to learn from experience without even being extremely
# programmed
# d) All of the above
# D
#
# 2. A) Training data is used to build a machine learning model
#
# 3. C) Good test dataset characteristic: large enough to yield meaningful results, representative of the dataset as a whole
# 4.
